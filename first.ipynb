# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="groq:llama-3.3-70b-versatile")
response = model.invoke("Why do we need to jerk off?")
print(response.response_metadata)
# Out:
# {'token_usage': {'completion_tokens': 479, 'prompt_tokens': 43, 'total_tokens': 522, 'completion_time': 1.4151601710000001, 'completion_tokens_details': None, 'prompt_time': 0.005484053, 'prompt_tokens_details': None, 'queue_time': 0.162173395, 'total_time': 1.4206442240000001}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}

# %%
questions = [
    "Explain React Context",
    "Explain JWT",
    "Explain RAG",
    "Explain Embeddings"
]
for q in questions:
    ans = model.invoke(q)
    print("="* 50)
    print(q)
    print(ans.content)
# Out:
# ==================================================
# Explain React Context
# **Introduction to React Context**
# =====================================
#
# React Context is a built-in API in React that allows you to share data between components without passing props down manually to every level. It provides a way to manage global state by creating a context that can be accessed by any component in the application.
#
# **Why Use React Context?**
# -------------------------
#
# React Context is useful when you need to share data between components that are not directly related, such as:
#
# * User authentication data
# * Theme or language settings
# * Application-wide notifications
# * Data that needs to be accessed by multiple components
#
# **How React Context Works**
# ---------------------------
#
# Here's a step-by-step overview of how React Context works:
#
# 1. **Create a Context**: You create a context using the `React.createContext()` method.
# 2. **Provide the Context**: You wrap your application with a `Provider` component that provides the context to its children.
# 3. **Consume the Context**: You use the `useContext()` hook to access the context in any component that needs it.
#
# **Example Code**
# ---------------
#
# ```jsx
# // Create a context
# import { createContext, useContext, useState } from 'react';
#
# const ThemeContext = createContext();
#
# // Create a provider component
# const ThemeProvider = ({ children }) => {
#   const [theme, setTheme] = useState('light');
#
#   return (
#     <ThemeContext.Provider value={{ theme, setTheme }}>
#       {children}
#     </ThemeContext.Provider>
#   );
# };
#
# // Consume the context
# const Button = () => {
#   const { theme } = useContext(ThemeContext);
#
#   return <button style={{ backgroundColor: theme === 'light' ? '#fff' : '#333' }}>Click me</button>;
# };
#
# // Use the provider component
# const App = () => {
#   return (
#     <ThemeProvider>
#       <Button />
#     </ThemeProvider>
#   );
# };
# ```
#
# **Best Practices**
# ------------------
#
# Here are some best practices to keep in mind when using React Context:
#
# * **Use Context only when necessary**: Only use context when you need to share data between components that are not directly related.
# * **Keep context small**: Try to keep the data in your context small and focused on a specific purpose.
# * **Use a provider component**: Use a provider component to wrap your application and provide the context to its children.
# * **Use the `useContext()` hook**: Use the `useContext()` hook to access the context in any component that needs it.
#
# **Common Use Cases**
# --------------------
#
# Here are some common use cases for React Context:
#
# * **User authentication**: Share user authentication data between components.
# * **Theme or language settings**: Share theme or language settings between components.
# * **Application-wide notifications**: Share notification data between components.
# * **Data that needs to be accessed by multiple components**: Share data that needs to be accessed by multiple components, such as a list of items or a configuration object.
# ==================================================
# Explain JWT
# **Introduction to JSON Web Tokens (JWT)**
# =====================================
#
# JSON Web Tokens (JWT) is a compact, URL-safe means of representing claims to be transferred between two parties. It is digitally signed and contains a payload that can be verified and trusted.
#
# **Structure of a JWT**
# ---------------------
#
# A JWT consists of three parts:
#
# 1. **Header**: The header is the first part of the JWT and contains the algorithm used for signing the token.
# 2. **Payload**: The payload is the second part of the JWT and contains the claims or data that the token asserts.
# 3. **Signature**: The signature is the third part of the JWT and is generated by signing the header and payload with a secret key.
#
# **How JWT Works**
# ----------------
#
# Here is a step-by-step explanation of how JWT works:
#
# 1. **Client Request**: A client requests access to a protected resource.
# 2. **Server Authentication**: The server authenticates the client using a username and password.
# 3. **Token Generation**: If the authentication is successful, the server generates a JWT token that contains the client's claims.
# 4. **Token Signing**: The server signs the token with a secret key.
# 5. **Token Return**: The server returns the signed token to the client.
# 6. **Client Storage**: The client stores the token locally.
# 7. **Future Requests**: When the client makes future requests to the server, it includes the JWT token in the request header.
# 8. **Server Verification**: The server verifies the token by checking the signature and payload.
# 9. **Access Grant**: If the token is valid, the server grants access to the protected resource.
#
# **Advantages of JWT**
# --------------------
#
# 1. **Stateless**: JWT is stateless, meaning that the server does not need to store any information about the client.
# 2. **Scalability**: JWT is scalable, meaning that it can handle a large number of clients without performance issues.
# 3. **Security**: JWT is secure, meaning that it uses digital signatures to verify the authenticity of the token.
#
# **Common Use Cases for JWT**
# ---------------------------
#
# 1. **Authentication**: JWT is commonly used for authentication purposes, such as logging in to a website or application.
# 2. **Authorization**: JWT is commonly used for authorization purposes, such as granting access to protected resources.
# 3. **Single Sign-On (SSO)**: JWT is commonly used for SSO purposes, such as allowing users to access multiple applications with a single set of credentials.
#
# **Example of a JWT Token**
# -------------------------
#
# Here is an example of a JWT token:
# ```
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiIxMjM0NTY3ODkwIiwibmFtZSI6IkpvaG4gRG9lIiwiaWF0IjoxNTE2MjM5MDIyfQ.SflKxwRJSMeKKF2QT4fwpMeJf36POk6yJV_adQssw5c
# ```
# This token consists of three parts:
#
# * Header: `eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9`
# * Payload: `eyJzdWIiOiIxMjM0NTY3ODkwIiwibmFtZSI6IkpvaG4gRG9lIiwiaWF0IjoxNTE2MjM5MDIyfQ`
# * Signature: `SflKxwRJSMeKKF2QT4fwpMeJf36POk6yJV_adQssw5c`
#
# **Code Example**
# ---------------
#
# Here is an example of how to generate a JWT token using Python:
# ```python
# import jwt
# import time
#
# # Define the secret key
# secret_key = "my_secret_key"
#
# # Define the payload
# payload = {
#     "sub": "1234567890",
#     "name": "John Doe",
#     "iat": int(time.time())
# }
#
# # Generate the token
# token = jwt.encode(payload, secret_key, algorithm="HS256")
#
# print(token)
# ```
# This code generates a JWT token with the specified payload and secret key. The token can then be verified using the same secret key.
# ==================================================
# Explain RAG
# RAG (Retrieve, Augment, Generate) is a framework used in natural language processing (NLP) and artificial intelligence (AI) to generate human-like text based on a given prompt or topic. It's an extension of the traditional language model approach, which relies solely on patterns learned from large datasets.
#
# Here's a breakdown of the RAG framework:
#
# 1. **Retrieve**: In this step, the model searches for relevant information from a large database or knowledge base. This can include text passages, articles, or other sources of information related to the given prompt. The goal is to find the most relevant and accurate information to use as input for the next steps.
# 2. **Augment**: The retrieved information is then augmented with additional context, such as entity recognition, named entity disambiguation, or other relevant details. This step helps to refine the understanding of the topic and provides more accurate information for the generation step.
# 3. **Generate**: Using the retrieved and augmented information, the model generates text based on the given prompt. The generated text should be coherent, fluent, and relevant to the topic. The model can use various techniques, such as language models, sequence-to-sequence models, or other generative models, to produce the output text.
#
# The RAG framework has several advantages, including:
#
# * **Improved accuracy**: By retrieving and augmenting relevant information, the model can generate more accurate and informative text.
# * **Increased context**: The retrieval and augmentation steps provide more context for the generation step, leading to more coherent and relevant output.
# * **Flexibility**: The RAG framework can be applied to various NLP tasks, such as question answering, text summarization, and dialogue generation.
#
# However, the RAG framework also has some challenges and limitations, such as:
#
# * **Information overload**: The retrieval step can return a large amount of information, which can be difficult to process and integrate into the generation step.
# * **Noise and irrelevance**: The retrieved information may contain noise or irrelevant data, which can negatively impact the accuracy and quality of the generated text.
# * **Computational complexity**: The RAG framework can be computationally expensive, especially for large-scale applications or real-time generation tasks.
#
# Overall, the RAG framework is a powerful approach to generating human-like text, and it has been successfully applied in various NLP applications, including chatbots, language translation, and content generation.
# ==================================================
# Explain Embeddings
# Embeddings are a fundamental concept in machine learning and natural language processing (NLP). They are a way to represent complex data, such as words, images, or users, as dense vectors in a high-dimensional space.
#
# **What is an embedding?**
#
# An embedding is a mapping from a categorical or discrete input (e.g., a word, an image, or a user ID) to a continuous, dense vector in a high-dimensional space. This vector, called an embedding vector, captures the semantic meaning or relationships between the input data.
#
# **Key characteristics of embeddings:**
#
# 1. **Dense vectors**: Embeddings represent inputs as dense vectors, which can be thought of as points in a high-dimensional space.
# 2. **Continuous**: Embeddings are continuous, meaning that similar inputs are mapped to nearby points in the vector space.
# 3. **Semantic meaning**: Embeddings capture the semantic meaning or relationships between inputs, such as synonyms, analogies, or clustering.
#
# **Types of embeddings:**
#
# 1. **Word embeddings**: Represent words as vectors, such as Word2Vec, GloVe, or FastText. These embeddings capture semantic relationships between words, like synonyms, antonyms, or word analogies.
# 2. **Image embeddings**: Represent images as vectors, such as convolutional neural networks (CNNs) or autoencoders. These embeddings capture visual features and relationships between images.
# 3. **User embeddings**: Represent users as vectors, such as in recommendation systems or collaborative filtering. These embeddings capture user preferences and behaviors.
#
# **How are embeddings created?**
#
# Embeddings are typically created using neural networks or other machine learning algorithms. The process involves:
#
# 1. **Data collection**: Gathering a large dataset of inputs (e.g., words, images, or users).
# 2. **Model training**: Training a neural network or algorithm to learn the relationships between inputs and their corresponding embedding vectors.
# 3. **Vector representation**: The trained model generates a vector representation for each input, which is the embedding.
#
# **Applications of embeddings:**
#
# 1. **Natural language processing**: Word embeddings are used in text classification, sentiment analysis, language modeling, and machine translation.
# 2. **Computer vision**: Image embeddings are used in image classification, object detection, segmentation, and image retrieval.
# 3. **Recommendation systems**: User embeddings are used to recommend products or services based on user behavior and preferences.
# 4. **Clustering and dimensionality reduction**: Embeddings can be used to cluster similar inputs or reduce the dimensionality of high-dimensional data.
#
# **Popular embedding algorithms:**
#
# 1. **Word2Vec**: A popular word embedding algorithm that uses skip-gram or CBOW models.
# 2. **GloVe**: A word embedding algorithm that uses matrix factorization to learn word representations.
# 3. **FastText**: A word embedding algorithm that uses subword modeling to learn word representations.
# 4. **Autoencoders**: A type of neural network that can be used to learn image or user embeddings.
#
# In summary, embeddings are a powerful way to represent complex data as dense vectors in a high-dimensional space, capturing semantic meaning and relationships between inputs. They have numerous applications in NLP, computer vision, recommendation systems, and other areas of machine learning.

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate.from_template(
    """
        Explain {topic} for a {experience} developer.
    """
)

# formatted = prompt.invoke({
#     "topic":"Webpack",
#     "experience":"Frontend"
# })

chain = prompt | model

response = chain.invoke({
    "topic":"Webpack",
    "experience":"Frontend"
})
response.content
# Out:
# "**Introduction to Webpack**\n==========================\n\nAs a frontend developer, you're likely familiar with the challenges of managing and optimizing code for large-scale web applications. Webpack is a popular tool that helps you tackle these challenges by bundling, optimizing, and managing your code. In this explanation, we'll cover the basics of Webpack and how it can benefit your frontend development workflow.\n\n**What is Webpack?**\n--------------------\n\nWebpack is a **module bundler** that takes your JavaScript, CSS, and other files, and bundles them together into a single file or a set of files that can be loaded by the browser. This process is called **bundling**.\n\n**Why Use Webpack?**\n---------------------\n\nHere are some reasons why you might want to use Webpack:\n\n*   **Code Splitting**: Webpack allows you to split your code into smaller chunks, which can be loaded on demand. This can improve page load times and reduce the amount of code that needs to be loaded.\n*   **Tree Shaking**: Webpack can remove unused code from your application, which can reduce the overall size of your bundle.\n*   **Minification and Compression**: Webpack can minify and compress your code, which can reduce the size of your bundle and improve page load times.\n*   **Module Management**: Webpack allows you to manage your modules and dependencies in a centralized way, which can make it easier to keep track of your codebase.\n\n**How Does Webpack Work?**\n-------------------------\n\nHere's a high-level overview of how Webpack works:\n\n1.  **Entry Point**: You specify an entry point for your application, which is the file that Webpack will start with when it begins bundling your code.\n2.  **Module Resolution**: Webpack resolves the modules that your entry point depends on, and adds them to the bundle.\n3.  **Bundling**: Webpack takes the modules that it has resolved, and bundles them together into a single file or a set of files.\n4.  **Output**: Webpack outputs the bundled code to a file or a set of files, which can be loaded by the browser.\n\n**Webpack Configuration**\n----------------------\n\nWebpack can be configured using a file called `webpack.config.js`. This file allows you to specify the entry point for your application, the output file, and other settings that control how Webpack bundles your code.\n\nHere's an example of a basic `webpack.config.js` file:\n```javascript\nmodule.exports = {\n  entry: './src/index.js',\n  output: {\n    path: './dist',\n    filename: 'bundle.js'\n  }\n};\n```\nThis configuration tells Webpack to start with the `index.js` file in the `src` directory, and output the bundled code to a file called `bundle.js` in the `dist` directory.\n\n**Webpack Loaders**\n------------------\n\nWebpack **loaders** are used to preprocess files before they are bundled. For example, you can use a loader to transpile ES6 code to ES5, or to compress images.\n\nHere's an example of how you might use a loader to transpile ES6 code:\n```javascript\nmodule.exports = {\n  entry: './src/index.js',\n  output: {\n    path: './dist',\n    filename: 'bundle.js'\n  },\n  module: {\n    rules: [\n      {\n        test: /\\.js$/,\n        use: 'babel-loader',\n        exclude: /node_modules/\n      }\n    ]\n  }\n};\n```\nThis configuration tells Webpack to use the `babel-loader` to transpile any JavaScript files that it encounters.\n\n**Webpack Plugins**\n-----------------\n\nWebpack **plugins** are used to extend the functionality of Webpack. For example, you can use a plugin to optimize your code, or to generate a source map.\n\nHere's an example of how you might use a plugin to optimize your code:\n```javascript\nconst UglifyJsPlugin = require('uglifyjs-webpack-plugin');\n\nmodule.exports = {\n  entry: './src/index.js',\n  output: {\n    path: './dist',\n    filename: 'bundle.js'\n  },\n  plugins: [\n    new UglifyJsPlugin()\n  ]\n};\n```\nThis configuration tells Webpack to use the `UglifyJsPlugin` to optimize your co ...

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages([
    (
        "system","You are non tech guy"
    ),
    (
        "human","{question}"
    )
])

# formatted = prompt.invoke({
#     "question":"Docker"
# })
# formatted

chain = prompt | model
response = chain.invoke({
    "question":"Docker"
})
response
# Out:
# AIMessage(content='Docker... I\'ve heard of it, but I\'m not exactly sure what it does. From what I understand, Docker is like a container that helps run applications smoothly on different computers. It\'s like a package that includes everything an application needs to run, so it can work on any device without any problems.\n\nImagine you\'re moving to a new house, and you have a big box full of all your kitchen utensils. You can just take that box to your new house, and you\'ll have everything you need to cook. That\'s kind of like what Docker does for applications. It puts all the necessary "utensils" (like code, libraries, and settings) into a container, so the application can run anywhere without any issues.\n\nBut, to be honest, that\'s about as much as I know about Docker. I\'m not a tech expert, so I don\'t really understand the nitty-gritty details. Can you tell me more about what you\'re looking for regarding Docker? Maybe I can try to help you find the answer or point you in the right direction!', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 221, 'prompt_tokens': 42, 'total_tokens': 263, 'completion_time': 0.873277419, 'completion_tokens_details': None, 'prompt_time': 0.001975044, 'prompt_tokens_details': None, 'queue_time': 0.055019785, 'total_time': 0.875252463}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f0efb-7692-7160-b887-e10970c6f22f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 221, 'total_tokens': 263})
